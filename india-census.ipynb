# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/indian-census-data-with-geospatial-indexing/district wise centroids.csv
# /kaggle/input/indian-census-data-with-geospatial-indexing/district wise population for year 2001 and 2011.csv
# /kaggle/input/indian-census-data-with-geospatial-indexing/state wise centroids_2011.csv
# /kaggle/input/indian-census-data-with-geospatial-indexing/state wise centroids_2001.csv
# /kaggle/input/indian-census-data-with-geospatial-indexing/district wise population and centroids.csv
# /kaggle/input/india-census/india-districts-census-2011.csv
# /kaggle/input/india-census/india_census_housing-hlpca-full.csv
# /kaggle/input/india-census/hlpca-colnames.csv

# %%
latlong = pd.read_csv('/kaggle/input/indian-census-data-with-geospatial-indexing/district wise centroids.csv')

# %% [markdown]
# *Number of districts*

# %%
#594 districts
latlong.shape
# Out:
# (594, 4)

# %%
latlong.head()
# Out:
#                  State         District   Latitude  Longitude
# 0  Andaman and Nicobar  Andaman Islands  12.382571  92.822911
# 1  Andaman and Nicobar  Nicobar Islands   7.835291  93.511601
# 2       Andhra Pradesh         Adilabad  19.284514  78.813212
# 3       Andhra Pradesh        Anantapur  14.312066  77.460158
# 4       Andhra Pradesh         Chittoor  13.331093  78.927639

# %%
latlong.tail()
# Out:
#            State           District   Latitude  Longitude
# 589  West Bengal  North 24 Parganas  22.062388  88.877940
# 590  West Bengal           Puruliya  23.254192  86.396853
# 591  West Bengal  South 24 Parganas  21.854428  88.445370
# 592  West Bengal     Uttar Dinajpur  26.044619  88.235952
# 593  West Bengal     West Midnapore  22.354897  87.231014

# %%
latlong.isnull().sum()
# Out:
# State        0
# District     0
# Latitude     0
# Longitude    0
# dtype: int64

# %%
latlong.duplicated().sum()
# Out:
# 0

# %%
census = pd.read_csv('/kaggle/input/india-census/india-districts-census-2011.csv')

# %%
census
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
cols = ['District code', 'Population', 'District name' , 'Male_Literate', 'Female_Literate','Male','Female', 'Literate', 'Households_with_Internet', 'Housholds_with_Electric_Lighting']

# %%
census[cols]
# Out:
#      District code  Population              District name  Male_Literate  \
# 0                1      870354                    Kupwara         282823
# 1                2      753745                     Badgam         207741
# 2                3      133487                Leh(Ladakh)          62834
# 3                4      140802                     Kargil          56301
# 4                5      476835                      Punch         163333
# ..             ...         ...                        ...            ...
# 635            636       41816                       Mahe          16610
# 636            637      200222                   Karaikal          79903
# 637            638       36842                   Nicobars          15397
# 638            639      105597  North  AND Middle Andaman          43186
# 639            640      238142              South Andaman         105794
#
#      Female_Literate    Male  Female  Literate  Households_with_Internet  \
# ...

# %%
final = latlong.merge(census, left_on ='District', right_on = 'District name').drop(columns = ['District name'])

# %%
final
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#          State name  Population     Male   Female  Literate  ...  \
# ...

# %%
final['sex_ratio'] = round((final['Female']/final['Male'])*100)

# %%
final['literacy_rate'] = round((final['Literate']/final['Population'])*100)

# %%
final.drop(columns = ['Male', 'Female', 'Literate'], inplace = True)

# %%
final.to_csv('India.csv', index = False)

# %% [markdown]
# ROUGH WORK

# %%
list_of_states = list(final['State'].unique())

# %%
list_of_states.insert(0, 'Overall India')

# %%
final
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#          State name  Population  Male_Literate  Female_Literate       SC  ...  \
# ...

# %%
import plotly.express as px

# %%
final.columns[5:]
# Out:
# Index(['State name', 'Population', 'Male_Literate', 'Female_Literate', 'SC',
#        'Male_SC', 'Female_SC', 'ST', 'Male_ST', 'Female_ST',
#        ...
#        'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
#        'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
#        'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity', 'sex_ratio',
#        'literacy_rate'],
#       dtype='object', length=115)

# %%
final.columns[3:]
# Out:
# Index(['Longitude', 'District code', 'State name', 'Population',
#        'Male_Literate', 'Female_Literate', 'SC', 'Male_SC', 'Female_SC', 'ST',
#        ...
#        'Power_Parity_Rs_150000_240000', 'Power_Parity_Rs_240000_330000',
#        'Power_Parity_Rs_150000_330000', 'Power_Parity_Rs_330000_425000',
#        'Power_Parity_Rs_425000_545000', 'Power_Parity_Rs_330000_545000',
#        'Power_Parity_Above_Rs_545000', 'Total_Power_Parity', 'sex_ratio',
#        'literacy_rate'],
#       dtype='object', length=117)

# %%
df = px.data.carshare()
fig = px.scatter_mapbox(final, lat = 'Latitude', lon = 'Longitude', zoom = 3, mapbox_style = 'carto-positron')
fig.show()
# Out:
# Failed to start the Kernel.
#
# Missing required @injectable annotation in: Yg.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
